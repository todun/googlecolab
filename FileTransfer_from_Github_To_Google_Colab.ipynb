# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/todun/googlecolab/blob/master/FileTransfer_from_Github_To_Google_Colab.ipynb)

# %%
# !pip install -q xlrd
# !git clone https://github.com/fastai/courses.git
# Out:
# Cloning into 'courses'...
# remote: Counting objects: 765, done.
# remote: Total 765 (delta 0), reused 0 (delta 0), pack-reused 765
# Receiving objects: 100% (765/765), 22.40 MiB | 34.28 MiB/s, done.
# Resolving deltas: 100% (409/409), done.

# %%
# Files from the cloned git repository.
# !ls courses/deeplearning1/excel
# Out:
# collab_filter.xlsx  entropy_example.xlsx  layers_example.xlsx
# conv-example.xlsx   graddesc.xlsm

# %%
import pandas as pd
df = pd.read_excel('courses/deeplearning1/excel/layers_example.xlsx')
df
# Out:
#                      x1        x2         x3  Unnamed: 3  Unnamed: 4  \
# NaN                   2  3.000000   1.000000         NaN         NaN
# NaN                 NaN       NaN        NaN         NaN         NaN
# NaN           weights 1       NaN        NaN         NaN         NaN
# NaN             1.77752 -0.056013   0.222363   -0.125313         NaN
# NaN             0.58263 -0.153056   0.122250    0.597437         NaN
# NaN            0.385083  0.402703   0.107784   -1.325171         NaN
# NaN                 NaN       NaN        NaN         NaN         NaN
# NaN       activations 1       NaN        NaN         NaN         NaN
# NaN             5.68802 -0.168491   0.919260    0.216514         NaN
# NaN             5.68802  0.000000   0.919260    0.216514         NaN
# NaN                 NaN       NaN        NaN         NaN         NaN
# NaN           weights 2       NaN        NaN         NaN         NaN
# NaN            -1.01076  0.470262   0.246334         NaN         NaN
# ...
